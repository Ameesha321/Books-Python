# %% [markdown]
# <a href="https://colab.research.google.com/github/Ameesha321/Books-Python/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.sample()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2843  Resort Hotel            0        146               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2843           November                        45                          1
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2843                        4                     5       2  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type    adr  \
# 2843    No Deposit   36.0     NaN                    0     Transient  56.16
#
#       required_car_parking_spaces  total_of_special_requests  \
# 2843                            0                          0
#
#       reservation_status reservation_status_date
# 2843           Check-Out              11-10-2015
#
# [1 rows x 32 columns]

# %%
df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 20817   Resort Hotel            0         10               2016
# 36319   Resort Hotel            0        112               2017
# 27750   Resort Hotel            0          3               2016
# 45420     City Hotel            0         72               2015
# 53881     City Hotel            1         44               2016
# 103833    City Hotel            0         41               2016
# 111969    City Hotel            0         13               2017
# 93751     City Hotel            0         20               2016
# 27460   Resort Hotel            0        272               2016
# 95272     City Hotel            0        132               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 20817            February                         7
# 36319                 May                        19
# 27750           September                        37
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
import numpy as np
import pandas as pd

# %%
labels=['w','x','y','z']
sample_list=[100,200,300,400]
array=np.array([1,2,3,4])
dict={'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(data=sample_list)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(data=sample_list,index=labels)
# Out:
# w    100
# x    200
# y    300
# z    400
# dtype: int64

# %%
pd.Series(sample_list,array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['cricket','football','basketball','golf'])
sports1
# Out:
# cricket       1
# football      2
# basketball    3
# golf          4
# dtype: int64

# %%
sports1["cricket"]
# Out:
# 1

# %%
sports2=pd.Series([11,2,3,4],index=['cricket','football','baseball','golf'])
sports2
# Out:
# cricket     11
# football     2
# baseball     3
# golf         4
# dtype: int64

# %%
sports1+sports2
# Out:
# baseball       NaN
# basketball     NaN
# cricket       12.0
# football       4.0
# golf           8.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns='score1 score2 score3 score4 score5'.split())
df1
# Out:
#      score1    score2    score3    score4    score5
# A  0.362908  0.487310  0.152240  0.588351  0.633531
# B  0.530432  0.892083  0.155992  0.944098  0.960509
# C  0.135899  0.716791  0.628568  0.326073  0.394731
# D  0.742652  0.625738  0.568198  0.468204  0.860942
# E  0.186882  0.674396  0.153256  0.890011  0.973133
# F  0.795489  0.331595  0.737520  0.484674  0.317485
# G  0.276753  0.115214  0.813662  0.991287  0.235233
# H  0.737708  0.081666  0.913174  0.131525  0.869231

# %%
df1["score3"]
# Out:
# A    0.152240
# B    0.155992
# C    0.628568
# D    0.568198
# E    0.153256
# F    0.737520
# G    0.813662
# H    0.913174
# Name: score3, dtype: float64

# %%
df1[["score1","score2","score3"]]
# Out:
#      score1    score2    score3
# A  0.362908  0.487310  0.152240
# B  0.530432  0.892083  0.155992
# C  0.135899  0.716791  0.628568
# D  0.742652  0.625738  0.568198
# E  0.186882  0.674396  0.153256
# F  0.795489  0.331595  0.737520
# G  0.276753  0.115214  0.813662
# H  0.737708  0.081666  0.913174

# %%
df1["score6"]=df1["score2"]+df1["score3"]
df1
# Out:
#      score1    score2    score3    score4    score5    score6
# A  0.362908  0.487310  0.152240  0.588351  0.633531  0.639550
# B  0.530432  0.892083  0.155992  0.944098  0.960509  1.048075
# C  0.135899  0.716791  0.628568  0.326073  0.394731  1.345359
# D  0.742652  0.625738  0.568198  0.468204  0.860942  1.193936
# E  0.186882  0.674396  0.153256  0.890011  0.973133  0.827652
# F  0.795489  0.331595  0.737520  0.484674  0.317485  1.069115
# G  0.276753  0.115214  0.813662  0.991287  0.235233  0.928876
# H  0.737708  0.081666  0.913174  0.131525  0.869231  0.994840

# %%
df2={'ID':['101','102','103','107','106'],'Name':['john','mercy','akash','kavin','lally'],'profit':[20,55,56,87,123]}
df=pd.DataFrame(df2)
df
# Out:
#     ID   Name  profit
# 0  101   john      20
# 1  102  mercy      55
# 2  103  akash      56
# 3  107  kavin      87
# 4  106  lally     123

# %%
df['ID']
# Out:
# 0    101
# 1    102
# 2    103
# 3    107
# 4    106
# Name: ID, dtype: object

# %%
df[['ID','Name']]
# Out:
#     ID   Name
# 0  101   john
# 1  102  mercy
# 2  103  akash
# 3  107  kavin
# 4  106  lally

# %%
df=df.drop("ID",axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-3d5ea2b63663> in <module>
# ----> 1 df=df.drop("ID",axis=1)
#       2 df
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df1["score1"]
# Out:
# A    0.362908
# B    0.530432
# C    0.135899
# D    0.742652
# E    0.186882
# F    0.795489
# G    0.276753
# H    0.737708
# Name: score1, dtype: float64
